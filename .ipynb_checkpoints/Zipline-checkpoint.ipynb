# %% [markdown]
# # Zipline Backtest Package Locally

# %% [markdown]
# ### Directions to install zipline locally
# 1. OPEN bash/shell
# 1. pip install zipline
# 1. zipline ingest -b quantopian-quandl

# %%
import sys
print(sys.version)
# Out:
# 3.6.4 |Anaconda custom (64-bit)| (default, Mar 12 2018, 20:05:31)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# #### Using Jupyter Magic to load zipline

# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %% [markdown]
# #### Demo Algo

# %%
from zipline.api import order, record, symbol

def initialize(context):
    pass

def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), "price"))

# %% [markdown]
# #### Run Above Algo
# 1. Note, strat.pickle is a pickled dataframe saved to the same file directory, in order to load check code below.

# %%
# %zipline --bundle quantopian-quandl --start 2008-1-1 --end 2012-1-1 -o strat.pickle
# Out:
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-02 21:00:00+00:00  194.840              NaN             0.000000e+00
# 2008-01-03 21:00:00+00:00  194.930         0.000001            -9.846500e-08
# 2008-01-04 21:00:00+00:00  180.050         0.000137            -1.506949e-05
# 2008-01-07 21:00:00+00:00  177.640         0.000112            -1.997931e-05
# 2008-01-08 21:00:00+00:00  171.250         0.000140            -3.923593e-05
# 2008-01-09 21:00:00+00:00  179.400         0.000290            -6.726635e-06
# 2008-01-10 21:00:00+00:00  178.020         0.000267            -1.371664e-05
# 2008-01-11 21:00:00+00:00  172.690         0.000299            -4.578399e-05
# 2008-01-14 21:00:00+00:00  178.780         0.000379            -3.244380e-06
# 2008-01-15 21:00:00+00:00  169.040         0.000529            -8.124990e-05
# 2008-01-16 21:00:00+00:00  159.640         0.000621            -1.659307e-04
# ...

# %% [markdown]
# #### Loading Pickled DF

# %%
import pandas as pd
df = pd.read_pickle("/Users/kevin/Dropbox/Github/Problem_Solving/Random-Projects/strat.pickle")
print(df.columns)
df.head()
# Out:
# Index(['AAPL', 'algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'long_exposure', 'long_value',
#        'longs_count', 'max_drawdown', 'max_leverage', 'net_leverage', 'orders',
#        'period_close', 'period_label', 'period_open', 'pnl', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_exposure', 'short_value',
#        'shorts_count', 'sortino', 'starting_cash', 'starting_exposure',
#        'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')
#                              AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-02 21:00:00+00:00  194.84              NaN             0.000000e+00
# 2008-01-03 21:00:00+00:00  194.93         0.000001            -9.846500e-08
# ...

# %% [markdown]
# #### Basic Graph of "Ending Cash" Column in DF

# %%
import matplotlib.pyplot as plt

plt.plot(df['ending_cash'])
plt.xticks(rotation=70)
plt.show()
