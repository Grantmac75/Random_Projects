# %%
import urllib.request
import requests
from bs4 import BeautifulSoup

url = "https://catalog.unr.edu/preview_program.php?catoid=25&poid=19885"
response = requests.get(url)
html = response.text

soup = BeautifulSoup(html, 'html.parser')

#print(soup.prettify())

print(soup.title)
print(soup.get_text('MATH'))
# a_tags = soup.find_all('a')

# for link in a_tags:
#     print(link.get('href'))
# Out:
# <title>Program: Mathematics (General Mathematics Specialization), B.S. - University of Nevada, Reno - Acalog ACMS™</title>
#
# MATH
# MATHProgram: Mathematics (General Mathematics Specialization), B.S. - University of Nevada, Reno - Acalog ACMS™MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHJavascript is currently not supported, or is disabled by this browser. Please enable Javascript for full functionality.MATH
# MATHvar gatewayFeatureSearchBar = true; var gatewayFeatureToolbarText = false; var gatewayFeatureBackToTopText = false;MATH
# MATH
# MATH
# MATH
# MATHdocument.getElementById("gateway-styles-nojs").parentNode.removeChild(document.getElementById("gateway-styles-nojs"));MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHSkip to ContentMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# $.noConflict();
# MATH
# MATH
# if (Prototype.BrowserFeatures.ElementExtensions) {
#                         var disablePrototypeJS = function (method, pluginsToDisable) {
#                                 var handler = function (event) {
#                                         event.target[method] = undefined;
#                                         setTimeout(function () {
#                                                 delete event.target[method];
#                                         }, 0);
#                                 };
#                                 pluginsToDisable.each(function (plugin) {
#                                         jQuery(window).on(method + '.bs.' + plugin, handler);
#                                 });
#                         },
#                                 pluginsToDisable = ['collapse', 'dropdown', 'modal', 'tooltip', 'popover', 'tab'];
#                         disablePrototypeJS('show', pluginsToDisable);
#                         disablePrototypeJS('hide', pluginsToDisable);
#                 }MATH
# MATH
# jQuery(document).ready(function ($) {
#                         if ($('#gateway-page').length) {
#
#                                 function wrap_table_block_n2_and_content() {
#                                         jQuery('table.block_n2_and_content').attr('id', 'table_block_n2_and_content_wrapper_fix_1');
#                                         jQuery('table.block_n2_and_content').parent().attr('id', 'table_block_n2_and_content_wrapper_fix_2');
#                                         var table_block_n2_and_content_wrapper = document.createElement('div');
#                                         table_block_n2_and_content_wrapper.setAttribute('id', 'table_block_n2_and_content_wrapper');
#                                         document.getElementById('table_block_n2_and_content_wrapper_fix_2').appendChild(table_block_n2_and_content_wrapper);
#                                         table_block_n2_and_content_wrapper.appendChild(document.getElementById('table_block_n2_and_content_wrapper_fix_1'));
#                                         jQuery('#table_block_n2_and_content_wrapper_fix_1, #table_block_n2_and_content_wrapper_fix_2').removeAttr('id');
#                                 }
#                                 wrap_table_block_n2_and_content();
#
#                                 $(document).ready(function () {
#                                         $(window).scroll(function () {
#                                                 if ($(this).scrollTop() > 100) {
#                                                         $('.topButton').addClass('fadeIn');
#                                                 } else {
#                                                         $('.topButton').removeClass('fadeIn');
#                                                 }
#                                         });
#                                         $('.topButton').click(function () {
#                                                 $("html, body").animate({ scrollTop: 0 }, 600);
#                                                 return false;
#                                         });
#                                 });
#
#
#                                 $(".main-overlay").click(function () {
#                                         if ($('.push-nav').hasClass('on')) {
#                                                 $('.push-nav').removeClass('on');
#                                         }
#                                 });
#
#                                 function removeTagAttibute(attributeName) {
#                                         var allTags = '*';
#                                         // var specificTags = ['ARTICLE', 'INPUT', 'SELECT', 'A'];
#                                         var allelems = document.querySelectorAll(allTags);
#                                         for (i = 0, j = 0; i < allelems.length; i++) {
#                                                 allelems[i].removeAttribute(attributeName);
#                                         }
#                                 }
#                                 removeTagAttibute('tabindex');
#
#                         }
#                 });
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHSkip to ContentMATH
# MATH
# MATH
# MATH
# MATH
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-88368820-1');
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity Home PageMATH MATHOpen Quick Links MenuMATH MATHCampus DirectoryMATH
# MATH
# MATH
# MATH
# MATH
# MATHMyNEVADAMATH
# MATH
# MATH
# MATHWebCampusMATH
# MATH
# MATH
# MATHEmail AccessMATH
# MATH
# MATH
# MATHCatalog, Calendar & ScheduleMATH
# MATH
# MATH
# MATHLibrariesMATH
# MATH
# MATH
# MATHFaculty & Staff FormsMATH
# MATH
# MATH
# MATH
# MATH
# MATHAboutMATH
# MATH
# MATH﻿MATH Main MenuMATH MATHAboutMATH
# MATH
# MATH
# MATHInteractive TourMATH
# MATH
# MATH
# MATHTop-Tier ExperienceMATH
# MATH
# MATH
# MATHVisiting CampusMATH
# MATH
# MATH
# MATHSince 1874MATH
# MATH
# MATH
# MATHReno & Lake TahoeMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHAdmissionsMATH
# MATH
# MATH﻿MATH Main MenuMATH MATHAdmissionsMATH
# MATH
# MATH
# MATHRequirementsMATH
# MATH
# MATH
# MATHApplyingMATH
# MATH
# MATH
# MATHResourcesMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHAcademicsMATH
# MATH
# MATH﻿MATH Main MenuMATH MATHAcademicsMATH
# MATH
# MATH
# MATHDegrees & ProgramsMATH
# MATH
# MATH
# MATHColleges & SchoolsMATH
# MATH
# MATH
# MATHOnline & AbroadMATH
# MATH
# MATH
# MATHHonors ProgramMATH
# MATH
# MATH
# MATHSupportMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHStudent LifeMATH
# MATH
# MATH﻿MATH Main MenuMATH MATHStudent LifeMATH
# MATH
# MATH
# MATHQuality of LifeMATH
# MATH
# MATH
# MATHLife TogetherMATH
# MATH
# MATH
# MATHOur LegacyMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHResearchMATH
# MATH
# MATH﻿MATH Main MenuMATH MATHResearchMATH
# MATH
# MATH
# MATHResearch ProfilesMATH
# MATH
# MATH
# MATHResearch ProjectsMATH
# MATH
# MATH
# MATHInfrastructureMATH
# MATH
# MATH
# MATHStudent OpportunitiesMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHImpactMATH
# MATH
# MATH﻿MATH Main MenuMATH MATHImpactMATH
# MATH
# MATH
# MATHEconomic DevelopmentMATH
# MATH
# MATH
# MATHStatewide DevelopmentMATH
# MATH
# MATH
# MATHArts & CultureMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHNevadaMATHTodayMATH
# MATH
# MATH
# MATHEventsMATH
# MATH
# MATH
# MATHCampus MapMATH
# MATH
# MATH
# MATHEqual Opportunity and Title IXMATH
# MATH
# MATH
# MATHMake a GiftMATH
# MATH
# MATH
# MATH
# MATH
# MATH
#
#         MATH
# MATH
# MATH
# MATH
#
#                 MATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity of Nevada, RenoMATH MATHExpand NavigationMATH MATHExpand Search boxMATH
# MATH
# MATH
# MATHSearch the University WebsiteMATH MATHSearchMATH
# MATH
# MATHor browse our sitemapMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity of Nevada, RenoMATH
# MATH
# MATH
# MATHNevadaMATH TodayMATH MATH|MATH
# MATH
# MATH
# MATHEventsMATH MATH|MATH
# MATH
# MATH
# MATHCampus MapMATH MATH|MATH
# MATH
# MATH
# MATHEqual Opportunity and Title IXMATH MATH|MATH
# MATH
# MATH
# MATHMake a GiftMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHSearch UNR.eduMATH
# MATH
# MATH
# MATH
# MATHSearch the University WebsiteMATH MATHSearchMATH
# MATH
# MATHor browse our sitemapMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHCampus DirectoryMATH
# MATH
# MATH
# MATHQuick links drop down menuMATH
# MATH
# MATH
# MATHMyNEVADAMATH
# MATH
# MATH
# MATHWebCampusMATH
# MATH
# MATH
# MATHEmail AccessMATH
# MATH
# MATH
# MATHCatalog, Calendar & ScheduleMATH
# MATH
# MATH
# MATHLibrariesMATH
# MATH
# MATH
# MATHFaculty & Staff FormsMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHAboutMATH
# MATH
# MATH
# MATHAdmissionsMATH
# MATH
# MATH
# MATHAcademicsMATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity of Reno, NevadaMATH
# MATH
# MATH
# MATH
# MATH
# MATHStudent LifeMATH
# MATH
# MATH
# MATHResearchMATH
# MATH
# MATH
# MATHImpactMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
#                     General Catalog
#                 MATH
# MATH
# MATHApply NowMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHAboutMATH
# MATH
# MATH
# MATH
# MATHInteractive TourMATH
# MATH
# MATH
# MATHTop-Tier ExperienceMATH
# MATH
# MATH
# MATHVisiting CampusMATH
# MATH
# MATH
# MATHSince 1874MATH
# MATH
# MATH
# MATHReno & Lake TahoeMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHAdmissionsMATH
# MATH
# MATH
# MATH
# MATHRequirementsMATH
# MATH
# MATH
# MATHApplyingMATH
# MATH
# MATH
# MATHResourcesMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHAcademicsMATH
# MATH
# MATH
# MATH
# MATHDegrees & ProgramsMATH
# MATH
# MATH
# MATHColleges & SchoolsMATH
# MATH
# MATH
# MATHOnline & AbroadMATH
# MATH
# MATH
# MATHHonors ProgramMATH
# MATH
# MATH
# MATHSupportMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHStudent LifeMATH
# MATH
# MATH
# MATH
# MATHQuality of LifeMATH
# MATH
# MATH
# MATHLife TogetherMATH
# MATH
# MATH
# MATHOur LegacyMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHResearchMATH
# MATH
# MATH
# MATH
# MATHResearch ProfilesMATH
# MATH
# MATH
# MATHResearch ProjectsMATH
# MATH
# MATH
# MATHInfrastructureMATH
# MATH
# MATH
# MATHStudent OpportunitiesMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHImpactMATH
# MATH
# MATH
# MATH
# MATHEconomic DevelopmentMATH
# MATH
# MATH
# MATHStatewide DevelopmentMATH
# MATH
# MATH
# MATHArts & CultureMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity of Reno, NevadaMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH MATHFacebookMATH
# MATH
# MATH
# MATH MATHTwitterMATH
# MATH
# MATH
# MATH MATHYoutubeMATH
# MATH
# MATH
# MATH MATHFlickrMATH
# MATH
# MATH
# MATH MATHInstagramMATH
# MATH
# MATH
# MATH MATHLinked InMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity of Nevada, Reno
#                     MATH
# MATH|
#                     MATH
# MATH1664 N. Virginia Street, Reno 89557
#                     MATH
# MATH|
#                     MATH
# MATH(775) 784-1110
#                     MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHWebsite HelpMATH MATH|MATH
# MATH
# MATH
# MATHContact UsMATH MATH|MATH
# MATH
# MATH
# MATHCopyrightMATH MATH|MATH
# MATH
# MATH
# MATHPrivacyMATH MATH|MATH
# MATH
# MATH
# MATHCommitment To AccessibilityMATH MATH|MATH
# MATH
# MATH
# MATHEqual Opportunity and Title IXMATH MATH|MATH
# MATH
# MATH
# MATHCommitment To DiversityMATH MATH|MATH
# MATH
# MATH
# MATHEmergency InformationMATH MATH|MATH
# MATH
# MATH
# MATHEmployment & CareersMATH MATH|MATH
# MATH
# MATH
# MATHDoing Business with UsMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# 				University of Nevada, Reno					MATH
# MATH
# MATH   MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHUniversity General Course Catalog 2018-2019 (DRAFT: Subject to revision 8/13/2018)MATH MATH
# MATH
# MATH
# MATH
# MATH
# MATH MATH MATHUniversity General Course Catalog 2018-2019 (DRAFT: Subject to revision 8/13/2018)MATH
# MATHUniversity General Course Catalog 2017-2018 [ARCHIVED CATALOG: LINKS AND CONTENT ARE OUT OF DATE. CHECK WITH YOUR ADVISOR.]MATH
# MATHUniversity General Course Catalog 2016-2017 [ARCHIVED CATALOG: LINKS AND CONTENT ARE OUT OF DATE. CHECK WITH YOUR ADVISOR.]MATH
# MATHUniversity General Course Catalog 2015-2016 [ARCHIVED CATALOG: LINKS AND CONTENT ARE OUT OF DATE. CHECK WITH YOUR ADVISOR.]MATH
# MATHUniversity General Course Catalog 2014-2015 [ARCHIVED CATALOG: LINKS AND CONTENT ARE OUT OF DATE. CHECK WITH YOUR ADVISOR.]MATH
# MATHUniversity General Course Catalog 2013-2014 [ARCHIVED CATALOG: LINKS AND CONTENT ARE OUT OF DATE. CHECK WITH YOUR ADVISOR.]MATH
# MATHUniversity General Course Catalog 2012-2013 [ARCHIVED CATALOG: LINKS AND CONTENT ARE OUT OF DATE. CHECK WITH YOUR ADVISOR.]MATH
# MATH
# MATH
# MATH
# 				MATH
#
# 						  				MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH MATH
# MATH
# MATH
# Jun 23, 2018		MATH
# MATH
# MATH MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHHELPMATH
# MATHUniversity General Course Catalog 2018-2019 (DRAFT: Subject to revision 8/13/2018)MATH MATH
# MATHMathematics (General Mathematics Specialization), B.S.MATH
# MATHPrint-Friendly PageMATH MATHAdd to MATHPortfolioMATH MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHDescriptionMATHThe department offers courses leading to the degree of bachelor of science with a major in mathematics. The bachelor’s degrees have specializations in applied mathematics, discrete mathematics/operations research, statistics, or general mathematics study. The bachelor of science degree is an “expanded major”, which provides a more intense experience in mathematics, computing and science. Students planning to major in mathematics are encouraged to consult an advisor from the Mathematics and Statistics Department to design a program of study in mathematics or statistics.MATH
# MATHhttp://www.unr.edu/assessment/plans-and-forms/science/math-ba-and-bsMATH
# MATHContact InformationMATH314 Davidson Mathematics and Science CenterMATH
# (775) 784-6773MATH
# MATHhttp://www.unr.edu/math/MATH
# MATHCollege of Science Academic Advisors:MATH MATHhttp://www.unr.edu/science/academic-advisingMATH
# MATHTransfer to the University of Nevada, RenoMATHUse the MATHtransfer agreementMATH MATH and the degree planner (available by clicking MATH at the top right of this page) to build your plan for graduation with your advisor. Course substitutions not identified on the transfer agreement require UNR advisor approval.MATH
# MATHIf a major-to-major transfer agreement is not available for your transfer institution, please check the MATHGeneral Core agreementMATH MATH if available. If neither is available, access established MATHtransfer course equivalenciesMATH to assist in your planning.MATH
# MATHGraduation RequirementsMATH MATH
# MATH
# MATH
# MATH
# MATHTotal UnitsMATH
# MATH120MATH
# MATH
# MATH
# MATHCumulative GPAMATH
# MATH2.0MATH
# MATH
# MATH
# MATHUniversity GPAMATH
# MATH2.0MATH
# MATH
# MATH
# MATHMajor GPAMATH
# MATH2.0MATH
# MATH
# MATH
# MATHResidency RequirementMATH
# MATH30 Upper-Division Units at UNRMATH
# MATH
# MATH
# MATHMajor Residency RequirementMATH
# MATH15 Upper-Division Units in the major at UNRMATH
# MATH
# MATH
# MATHUpper-Division RequirementMATH
# MATH40 Upper-Division UnitsMATH
# MATH
# MATH
# MATHHalf Program Units/4 Year InstitutionMATH
# MATH60 UnitsMATH
# MATH
# MATH
# MATH
# MATH MATH
# MATHI. Silver Core General Education Requirements (25-28 units)MATHNOTE:MATH Refer to the Core Curriculum chapter of this catalog for information regarding the “MATHCore English and Math Completion Policy MATH MATH.”MATH
# MATHStudents in this major must meet all Silver Core Objectives (CO1 through CO14). Courses satisfying Core Objectives are designated (e.g., CO9) in General Catalog curricula and course description.MATH
# MATHA. Silver Core Writing and Prerequisite (3-6 units) - CO1, CO3MATHENG 101 - Composition  I MATH  (3 units)MATHENG 102 - Composition II MATH  (3 units) CO1, CO3MATHNOTE:MATH MATHENG 100JMATH MATH may substitute for ENG 101. Students who place in ENG 102 are not required to complete ENG 101 or ENG 100J.MATHB. Silver Core Mathematics (4 units) - CO2MATHMATH 181 - Calculus I MATH  (4 units) CO2MATHC. Silver Core Natural Sciences (6 units minimum) - CO4, CO4LMATHRefer to the Core Curriculum chapter for a list of approved MATHCO4/CO4L coursesMATH MATH.MATH
# MATHD. Silver Core Social Sciences (3 units) - CO6MATHRefer to the Core Curriculum chapter for a list of approved MATHCO6 coursesMATH MATH.MATH
# MATHE. Silver Core Fine Arts (3 units) - CO7MATHRefer to the Core Curriculum chapter for a list of approved MATHCO7 coursesMATH MATH.MATH
# MATHF. Silver Core Humanities (6 units) - CO5, CO8MATHRefer to the MATHCore CurriculumMATH MATH  chapter in this catalog.MATH
# MATHII. Additional Silver Core Requirements (15 units maximum)MATHStudents must take courses that satisfy the following Core Objectives. Some or all of these Silver Core Objectives may be satisfied in the Major Requirements (Section IV). Refer to the MATHCore CurriculumMATH MATH  chapter in this catalog.MATH
# MATHA. Science, Technology & Society Course - CO9MATHRefer to the Core Curriculum chapter for a list of approved MATHCO9 coursesMATH MATH.MATH
# MATHB. Diversity & Equity Course - CO10MATHRefer to the Core Curriculum chapter for a list of approved MATHCO10 coursesMATH MATH.MATH
# MATHC. Global Context Course - CO11MATHRefer to the Core Curriculum chapter for a list of approved MATHCO11 coursesMATH MATH.MATH
# MATHD. Ethics Course - CO12MATHCS 135 - Computer Science I MATH  (3 units) CO12 (units counted in Major Requirement) MATHE. Capstone Integration & Synthesis Course - CO13MATHMATH 420 - Mathematical Modeling MATH  (3 units) CO13, CO14 MATHORMATHMATH 487 - Deterministic Operations Research MATH  (3 units) CO13MATHF. Application Course - CO14MATHMATH 420 - Mathematical Modeling MATH  (3 units) CO13, CO14 MATHORMATHSCI 435 - STEM Education Outreach Experience MATH  (1 to 3 units) CO14MATHIII. Additional College Requirements (0 units)MATHIV. Major Requirements , General Mathematics (53 units)MATHCS 135 - Computer Science I MATH  (3 units) CO12MATHCS 202 - Computer Science II MATH  (3 units)MATHMATH 181 - Calculus I MATH  (4 units) CO2 (units counted in General Education Requirement) MATHMATH 182 - Calculus II MATH  (4 units)MATHMATH 283 - Calculus III MATH  (4 units)MATHMATH 285 - Differential Equations MATH  (3 units)MATHMATH 295 - Proof Writing for the Math/Stat Major MATH  (3 units)MATHMATH 310 - Introduction to Analysis I MATH  (3 units)MATHMATH 311 - Intro To Analysis II MATH  (3 units)MATHMATH 330 - Linear Algebra MATH  (3 units)MATHMATH 331 - Groups, Rings and Fields MATH  (3 units)MATHMATH 440 - Topology MATH  (3 units)MATHSTAT 461 - A First Course in Probability MATH  (3 units)MATHAdditional MATH/STAT courses numbered 300-499, except MATHSTAT 352MATH MATH, MATHMATH 302MATH MATH (15 units)MATHV. Minor Requirements (18-21 units)MATHStudents may complete any minor approved by the University, except that students may not receive credit for both a minor and a major in the same discipline. Completion of a second major or degree approved by the university satisfies this requirement.MATH
# MATHVI. Electives (3-9 units)MATHVII. Recommended Schedule MATHWe assume a 21 unit minor.  Students who opt to complete an 18 unit minor, must take 3 additional elective units to obtain 120 units.MATH
# MATHA. First YearMATHFall Semester (14 units)MATHMATH 181 - Calculus I MATH  (4 units) CO2MATHENG 101 - Composition  I MATH  (3 units)MATHCS 135 - Computer Science I MATH  (3 units) CO12MATHSocial Sciences Course (3 units) CO6MATHSCI 110 - First Year Experience I: Science and Mathematics MATH  (1 unit)MATHSpring Semester (16 units)MATHMATH 182 - Calculus II MATH  (4 units)MATHENG 102 - Composition II MATH  (3 units) CO1, CO3MATHCS 202 - Computer Science II MATH  (3 units)MATHMinor (3 units)MATHNatural Sciences Course (3 units) CO4LMATHB. Second YearMATHFall Semester (16 units)MATHCH 201 - Ancient and Medieval Cultures MATH  (3 units) CO5 MATHORMATHCH 202 - The Modern World MATH  (3 units) CO5MATHMATH 283 - Calculus III MATH  (4 units)MATHMinor (3 units)MATHFine Arts Course (3 units) CO7MATHDiversity & Equity Course (3 units) CO10MATHSpring Semester (16 units)MATHMATH 285 - Differential Equations MATH  (3 units)MATHMATH 295 - Proof Writing for the Math/Stat Major MATH  (3 units)MATHCH 203 - American Experiences  and Constitutional Change MATH  (3 units) CO5, CO8MATHMinor (3 units)MATHNatural Sciences Course (4 units) CO4 or CO4LMATHC. Third YearMATHFall Semester (16 units)MATHMATH 310 - Introduction to Analysis I MATH  (3 units)MATHMATH 330 - Linear Algebra MATH  (3 units)MATHMinor (3 units)MATHGeneral Elective (4 units)MATHMATH/STAT Elective (3 units)MATHSpring Semester (15 units)MATHMATH 311 - Intro To Analysis II MATH  (3 units)MATHMATH 440 - Topology MATH  (3 units)MATHMATH/STAT Elective (3 units) MATHMinor (3 units)MATHScience, Technology & Society Course (3 units) CO9MATHD. Fourth YearMATHFall Semester (15 units)MATHSTAT 461 - A First Course in Probability MATH  (3 units)MATHMATH 331 - Groups, Rings and Fields MATH  (3 units)MATHMATH/STAT Elective (3 units) MATHGlobal Contexts Course (3 units) CO11MATHMinor (3 units)MATHSpring Semester (12 units)MATHMATH 420 - Mathematical Modeling MATH  (3 units) CO13, CO14MATHMATH/STAT Electives (6 units) MATHMinor (3 units)MATHNote(s):MATHThe Math/Stat elective may be any MATH or STAT course numbered 300-499, except for MATHMATH 302MATH MATH, MATHSTAT 352MATH MATH. For those contemplating studying pure mathematics in graduate school, good choices include MATHMATH 410MATH MATH - Complex Analysis , MATHMATH 441MATH MATH - Intro Algebraic Topology , and/or MATHMATH 430MATH MATH - Linear Algebra II.MATH
# MATH MATH
# MATH
# MATH
# MATH MATHBack to TopMATH | MATHPrint-Friendly PageMATH MATHAdd to MATHPortfolioMATH MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHGlobal SearchMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATHCatalog SearchMATH MATH
# MATH
# MATHChoose Search LocationMATH
# MATH
# MATHSelect an optionMATH
# MATHCoursesMATH
# MATHProgramsMATH
# MATHHierarchy ItemsMATH
# MATHOther ContentMATH
# MATHEntire CatalogMATH
# MATH
# MATH
# MATH
# MATH MATHWhole Word/PhraseMATH
# MATHAdvanced SearchMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH  MATHCatalog HomeMATH
# MATH  MATH1. Reader's Guide to the CatalogMATH MATH
# MATH  MATH2. University Mission, Organization, ServicesMATH MATH
# MATH  MATH3. Admission, Transfer, and Examination CreditMATH MATH
# MATH  MATH4. Academic Policies for Registration, Records, and GraduationMATH MATH
# MATH  MATH5. Financial Aid, Tuition and FeesMATH MATH
# MATH  MATH6. Academic CalendarMATH MATH
# MATH  MATH7. Core CurriculumMATH MATH
# MATH  MATH8. Course DescriptionsMATH MATH
# MATH  MATH9. Colleges, Schools & Degrees OfferedMATH MATH
# MATH  MATH10. Degree ProgramsMATH MATH
# MATH  MATH11. Policies and GuidelinesMATH MATH
# MATH  MATH12. List of FacultyMATH MATH
# MATH  MATH13. Archived CatalogsMATH MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH   MATHMy PortfolioMATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH
# MATH   MATH
# MATH
# MATH
# MATH
# MATHAll MATHcatalogsMATH © 2018 University of Nevada, Reno.MATH MATHPowered by the MATHAcalog™ Academic Catalog Management System™ (ACMS™)MATH.MATH
# MATH
# MATH
# 		function showMobile(){
# 			var name = 'acalogMobileApp';
# 			var value = 'mobile';
#
# 			var date = new Date();
# 			date.setTime(date.getTime()+(365*24*60*60*1000));
# 			var expires = "; expires="+date.toGMTString();
# 			document.cookie = name+"="+value+expires+"; path=/";
# 		}
# 	MATH
# MATHMobile SiteMATH.MATH
# 	var _gaq = _gaq || [];
# 	_gaq.push(['_setAccount', 'UA-16369563-1']);
# 	_gaq.push(['_trackPageview']);
# 	(function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	})();
# MATH
# MATH   MATH
# MATH
# MATH
# MATH MATH
# MATH

# %%
import urllib.request
import requests
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup

url = "https://catalog.unr.edu/preview_program.php?catoid=25&poid=19885"

uClient = uReq(url)
page_html = uClient.read()
uClient.close()

page_soup = soup(page_html, "html.parser")
page_soup.p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-089621ecd72e> in <module>()
#      11
#      12 page_soup = soup(page_html, "html.parser")
# ---> 13 page_soup.p
#
# /Users/kevin/anaconda/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'p'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?
